# %%
import pandas as pd 
import sqlite3 as sql
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cnx = sql.connect('/content/drive/MyDrive/Canadian_Hurricane_Impact.db')

# %%
cocorahs = pd.read_sql_query('SELECT * FROM Complete_impact', cnx)

# %%
metar = pd.read_sql_query('SELECT * FROM Filtered_Metar_Data', cnx)

# %%
clim_data = pd.read_sql_query('SELECT * FROM Filtered_Climate_Data', cnx)

# %%
cnx.close()

# %%
clim_data.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17755 entries, 0 to 17754
# Columns: 32 entries, Longitude (x) to Hurricane_Name
# dtypes: float64(12), int64(3), object(17)
# memory usage: 13.1 MB

# %%
metar.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439620 entries, 0 to 439619
# Columns: 32 entries, station to snowdepth
# dtypes: float64(19), object(13)
# memory usage: 420.2 MB

# %%
cocorahs.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8490 entries, 0 to 8489
# Columns: 11 entries, ObservationDate to Hurricane_Name
# dtypes: float64(3), object(8)
# memory usage: 4.7 MB

# %%
# clim_data.isnull().sum(axis = 0)
# metar.isnull().sum(axis = 0)
# cocorahs.isnull().sum(axis = 0)

# %%
clim_data = clim_data.convert_dtypes()
metar = metar.convert_dtypes()
cocorahs = cocorahs.convert_dtypes()

# %%
clim_data.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17755 entries, 0 to 17754
# Columns: 32 entries, Longitude (x) to Hurricane_Name
# dtypes: Float64(10), Int64(5), string(17)
# memory usage: 16.4 MB

# %%
metar.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439620 entries, 0 to 439619
# Columns: 32 entries, station to snowdepth
# dtypes: Float64(10), Int64(9), string(13)
# memory usage: 428.2 MB

# %%
cocorahs.info(memory_usage='deep', verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8490 entries, 0 to 8489
# Columns: 11 entries, ObservationDate to Hurricane_Name
# dtypes: Float64(3), string(8)
# memory usage: 4.7 MB

# %%
conn = sql.connect('/content/drive/MyDrive/Canadian_Hurricane_Impact_Completed.db')

# %%
clim_data.to_sql('Climate_Data', conn, if_exists='replace', index = False)
metar.to_sql('Metar_Data', conn, if_exists='replace', index = False)
cocorahs.to_sql('CoCoRaHS_Data', conn, if_exists='replace', index = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
conn.close()
